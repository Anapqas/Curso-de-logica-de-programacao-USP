# %%
#week2ex1
l = int(input("Digite o valor correspondente ao lado de um quadrado:"))

p = 4*l

a = l**2

print("perímetro:", p,"- área:", a)

# %%
#week2ex2
n1 = int(input("Digite a primeita nota:"))
n2 = int(input("Digite a segunda nota:"))
n3 = int(input("Digite a terceira nota:"))
n4 = int(input("Digite a quarta nota"))

média = (n1+n2+n3+n4)/4

print("A média aritimética é", média)

# %%
#week2 ex1adcional
nome = input("Digite o nome do cliente:")
diavencimento = input("Digite o dia de vencimento:")
mesvencimento = input("Digite o mês de vencimento:")
fatura = input("Digite o valor da fatura")

print("Olá,", nome)
print("A sua fatura com vencimento em", diavencimento, "de", mesvencimento, "no valor de R$", fatura, "está fechada." )

# %%
#week2 ex2adicional
seg_str = input('Por favor, entre com o número de segundos que deseja converter:')
seg_int = int(seg_str)

dias = seg_int//86400
horas = (seg_int%86400)//3600
minutos = ((seg_int%86400)%3600)//60
segundos = ((seg_int%86400)%3600)%60

print('O resultado da conversão é', dias, "dias", horas, 'horas', minutos, 'minutos e', segundos, "segundos")

# %%
#desafiobaskara
import math
a = int(input("a"))
b = int(input("b"))
c = int(input("c"))

d = (b**2 - 4*a*c)

if (d>0):
  print("Há duas raizes reais")
  print("O valor é", (-b+math.sqrt(d))/(2*a))
  print("O valor é", (-b-math.sqrt(d))/(2*a))
else:
  if (d<0):
    print("não há raizes reais")
  else:
    print("Há uma raiz real")
    print("O valor é", (-b+math.sqrt(d))/(2*a))

# %%
#week3 ex1

a = int (input("escreva um numero"))


if (a%2 == 0):
  print("par")
else:
  print("impar")

# %%
#week3 ex2
a = int(input("Escreva um número:"))

if ( a%3 == 0):
  print("Fizz")
else:
  print(a)

# %%
#week3 ex4
a = int(input("Escreva um número:"))

if ( a%3 == 0 and a%5 == 0 ):
  print("FizzBuzz")
else:
  print(a)

# %%
#week3 ex5

a = int(input("Escreva um número:"))
b = int(input("Escreva um número:"))
c = int(input("Escreva um número:"))

if (b>a and c>b):
  print("crescente")
else:
  print("não está em ordem crescente")

# %%
#week 4 

i=0
while i<=10:
  print(2**i)
  i= i+1
soma = 0
valor=1
while valor != 0:
  valor = int(input("Digite uma sequencia de numero, terminada em zero"))
  soma = soma + valor
  print(soma)

# %%
#desafio while
i = input("Digite um número:")
x = 0
soma = 0
while x < len(i):
  parcela = (int(i)//10**x)%10
  x = x + 1
  soma = soma + parcela 
print(soma)

# %%
#week4 ex1

n = int(input("Digite um número:"))
x = 0
produto = 1
while x != n :
  fatores = n - x
  x = x + 1
  produto = produto*fatores

print(produto)

# %%
#week4 ex2
n = int(input("Digite o valor de n:"))
x=0
while x != 2*n-1:
  x=x+1
  if x%2 != 0:
   print(x)

# %%
#week4 ex3
n = input("Digite um número inteiro:")
x = 0
soma = 0
while x != len(n):
  parcela = (int(n)//10**x)%10
  x = x+1
  soma = soma + parcela

print(soma)

# %%
#week4 ex1adcional
n = int(input("Digite um número inteiro:"))
x=2
primo = True

while x<n and primo:
  teste = n%x
  x=x+1
  if teste == 0 :
    primo = False
  

if primo:
  print("primo")
else:
  print("nao primo")

# %%
#week4 ex2adicional
n = int(input("Digite um número inteiro:"))
x = 1
noadjacente = True
anterior = (n//10**0)%10
teste = 0 

while x < len(str(n)) and  noadjacente:
   digitos = (n//10**x)%10
   x=x+1
   teste = digitos - anterior
   anterior = digitos
   if teste == 0:
     noadjacente = False
  

if noadjacente == False:
  print("sim")
else:
  print("não")

# %%
#week5 desafio
def fatorial(n):
  x=0
  produto = 1
  while x != n:
    fator =  n - x 
    x = x + 1 
    produto = produto*fator 
  return produto

def binomial(n,k):
  bi = fatorial(n)/(fatorial(k)*fatorial(n-k))
  return bi

print (binomial(5,3))

# %%
#testes automatizados
def fatorial(n):
  x=0
  produto = 1
  while x != n:
    fator =  n - x 
    x = x + 1 
    produto = produto*fator 
  return produto

def testa_fatorial():
  if fatorial(1)==1:
    print("Funciona para 1")
  else:
    print("Não funciona para 1")
  if fatorial(2)==2:
    print("Funciona para 2")
  else:
    print("Não funciona para 2")
  if fatorial(0)==1:
    print("Funciona para 0")
  else:
    print("Não funciona para 0")
  if fatorial(5)==120:
    print("Funciona para 5")
  else:
    print("Não funciona para 5")
print(testa_fatorial())

# %%
#teste
def troca(x, y):
    aux = x
    x = y
    y = aux

x = 10
y = 20
troca (x,y)
print("x =", x,"e y =",y)

# %%
#week5 ex1
def maximo (x,y):
  if x>y:
    return x
  else:
    return y 

print(maximo(3,6), maximo(5,8), maximo(18,8), maximo(1,54))

# %%
#week5 ex2
def ePrimo(n):
 x=2
 primo = True
 while x<n and primo:
    teste = n%x
    x=x+1 
    if teste == 0 : 
      primo = False
 if (primo): 
   return n
 else:
   return 0

def maior_primo (n):
 k=1
 resposta = 0
 while (k<=n): 
   ePrimo(k)
   if (ePrimo (k) != 0):
       resposta = k
   k = k+1
 return resposta

# %%
#week5 ex3
def vogal (n):
  if n=="a"or n=="A" or n=="e" or n=="E" or n=="i" or n=="I" or n=="o" or n=="O"or n=="u" or n=="U":
    return True
  else:
    return False

print(vogal ("a"))
print(vogal ("b"))
print(vogal ("y"))

# %%
#week5 ex1adcional
def fizzbuzz (n):
  if n%3==0 and n%5!=0:
   return 'Fizz'
  else:
    if n%3!=0 and n%5==0:
      return 'Buzz'
    else:
      if n%3==0 and n%5==0:
        return 'FizzBuzz'
      else:
        return n

# %%
#week5 ex2adcional
def maximo (x,y,z):
  if x>y and x>z:
    return x
  else:
    if y>x and y>z:
      return y
    else:
      return z
   

print(maximo(3,6,9), maximo(5,8,1), maximo(18,8,6), maximo(1,54,89))

# %%
#jogo NIM - desafio 
#jogo do nim versão CORRIGIDA
def computador_escolhe_jogada (n,m):
  if n%(m+1)==0 or n%(m+1)>m:
    print("O computador tirou", m, "peças.")
    return m
  else:
    print("O computador tirou", n%(m+1), "peças.")
    return n%(m+1)

def usuario_escolhe_jogada (n,m):
  jogadavalida = False
  while not jogadavalida:
    i= int(input("Quantas peças você vai tirar?"))
    if i>0 and i<=m:
      jogadavalida = True 
    else:
      print("Oops! Jogada inválida! Tente de novo.")
  print("Voce tirou", i, "peças.")
  return i

def partida ():
  n = int(input("Quantas peças?"))
  m = int(input('Limite de peças por jogada?'))
  if n%(m+1)==0:
    print("Você começa!")
    while n>0:
     n = n-usuario_escolhe_jogada(n,m)
     if n==0:
       print("Você ganhou!")
     else:
        print("Agora restam", n, "peças no tabuleiro")
     n = n-computador_escolhe_jogada(n,m)
     if n==0:
       print("O computador ganhou!")
     else:
        print("Agora restam", n, "peças no tabuleiro")

  else:
    print("Computador começa!")
    while n>0:
      n= n-computador_escolhe_jogada(n,m)
      if n==0:
        print("O computador ganhou!")
      else:
        print("Agora restam", n, "peças no tabuleiro")
        n = n-usuario_escolhe_jogada(n,m)
        if n==0:
          print("Você ganhou!")
        else:
          print("Agora restam", n, "peças no tabuleiro")
    
def campeonato():
   print("**** Rodada 1 ****")
   partida()
   print("**** Rodada 2 ****")
   partida()
   print("**** Rodada 3 ****")
   partida()
   print("**** Final do campeonato! ****")
   print('Placar: Você 0 X 3 Computador')

def main():
  print("Bem-vindo ao jogo do NIM! Escolha:")
  escolha = int(input("1 - para jogar uma partida isolada 2 - para jogar um campeonato"))
  if escolha == 1:
    partida()
  else:
    if escolha == 2:
      campeonato()
    
print(main())

# %%
#week7 ex1
h = int(input("digite a largura:"))
l= int(input("digite a altura:"))

x=1
y=1
while y<=l:
  while x<=h:
    print("#", end='')
    x=x+1
  print()
  x=1
  y=y+1

# %%
#week7 ex2
h = int(input("digite a altura:"))
l= int(input("digite a largura"))

altura=1
largura=1
while altura<=h:
  while largura<=l:
    if altura ==1 or altura==h:
      print("#", end="")
      largura=largura+1
    else:
      if largura==1 or l==largura:
        print("#", end="")
        largura=largura+1
      else:
        print(" ", end="")
        largura=largura+1
  print()
  largura=1
  altura=altura+1

# %%
#week7 ex2 INVERTIDO
h = int(input("digite a largura:"))
l= int(input("digite a altura"))

altura=1
largura=1
while altura<=h:
  while largura<=l:
    if altura ==1 or altura==h:
      print("#", end="")
      largura=largura+1
    else:
      if largura==1 or l==largura:
        print("#", end="")
        largura=largura+1
      else:
        print(" ", end="")
        largura=largura+1
  print()
  largura=1
  altura=altura+1

# %%
#week8 ex1
lista = []
lista = []
def remove_repetidos (lista):
  lista.sort()
  ord=[]
  for x in lista:
    if x not in ord:
      ord.append(x)
  return ord

# %%
#week8 ex2
lista = [10,15,30,100]
def soma_elementos(lista):
  soma=[0]
  for x in lista:
    y=x+soma[-1]
    soma.append(y)
  return soma[-1]  

print(soma_elementos(lista))

# %%
#week8 ex1adicional
lista = [-20,30,0]
def maior_elemento(lista):
  lista.sort()
  return lista[-1]

print(maior_elemento(lista))

# %%
#week8 ex2adicional
  n=1
  lista=[]
  while n!=0:
    n= int(input("Digite um número:"))
    if n!=0:
      lista.append(n)
  caracter=len(lista)-1
  while caracter>=0:
    print(lista[caracter])
    caracter=caracter-1
